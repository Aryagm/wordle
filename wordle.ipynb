# %% [markdown]
# # Imports

# %%
import requests
import ast
import pendulum
import numpy as np

# %% [markdown]
# # 1. Get list of all possible words

# %%
def get_remote_file(path):
    text = requests.get(path)
    return text.text

# %%
full_file = get_remote_file("https://www.nytimes.com/games/wordle/main.e17c80f8.js")

# %%
word_list_str = full_file[full_file.index("var mo=")+7:full_file.index("fanny\"]")+7]
word_list = ast.literal_eval(word_list_str)

# %%
print(len(word_list))
# Out:
# 2309

# %%
word_list[:10]
# Out:
# ['cigar',
#  'rebut',
#  'sissy',
#  'humph',
#  'awake',
#  'blush',
#  'focal',
#  'evade',
#  'naval',
#  'serve']

# %% [markdown]
# # 2. Easy Solution

# %% [markdown]
# The word list is chronological, it contains all the words in the order they are going to appear on wordle. So it is possible to create a dictionary for each word with the date it will appear on wordle.

# %%
todays_date = "2022-04-25"
todays_word = "askew"

# %%
words_dict = {}
words_dict[todays_date] = todays_word

# %%
# get all words in word_list after todays_word:
word_list_future = word_list[word_list.index(todays_word)+1:]

for word in word_list_future:
    words_dict[pendulum.parse(str(todays_date)[0:10]).add(days=1).format("YYYY-MM-DD")] = word
    todays_date = pendulum.parse(str(todays_date)[0:10]).add(days=1).format("YYYY-MM-DD")

todays_date = pendulum.parse("2022-04-25")

# get all words in word_list before todays_word:
word_list_past = word_list[:word_list.index(todays_word)]

for word in word_list_past[::-1]:
    words_dict[pendulum.parse(str(todays_date)[0:10]).subtract(days=1).format("YYYY-MM-DD")] = word
    todays_date = pendulum.parse(str(todays_date)[0:10]).subtract(days=1).format("YYYY-MM-DD")

# %%
print(dict(list(words_dict.items())[-10:]))
# Out:
# {'2021-06-28': 'serve', '2021-06-27': 'naval', '2021-06-26': 'evade', '2021-06-25': 'focal', '2021-06-24': 'blush', '2021-06-23': 'awake', '2021-06-22': 'humph', '2021-06-21': 'sissy', '2021-06-20': 'rebut', '2021-06-19': 'cigar'}

# %% [markdown]
# Now we will sort the dictionary by order of words based on word_list. This step is not necessary but knowing that the dictionary is sorted chronologically helps me sleep better at night.

# %%
sorted_words_dict = {}
for word in word_list:
    word_date = list(words_dict.keys())[list(words_dict.values()).index(word)]
    sorted_words_dict[word_date] = word

# %%
# Printing last 10 wordles!
print(dict(list(sorted_words_dict.items())[-10:]))
# Out:
# {'2027-10-05': 'hydro', '2027-10-06': 'liege', '2027-10-07': 'octal', '2027-10-08': 'ombre', '2027-10-09': 'payer', '2027-10-10': 'sooth', '2027-10-11': 'unset', '2027-10-12': 'unlit', '2027-10-13': 'vomit', '2027-10-14': 'fanny'}

# %% [markdown]
# Getting a days wordle is as easy as accessing the index in sorted_words_dict by the date!

# %%
def get_todays_wordle():
    return sorted_words_dict[pendulum.parse(str(pendulum.today())[0:10]).format("YYYY-MM-DD")]

print(get_todays_wordle())
# Out:
# shown

# %% [markdown]
# Lets also write a function to get the wordle for any date

# %%
def get_wordle_date(year, month, day):
    if len(str(month))==1:
        month = "0"+str(month)
    if len(str(day))==1:
        day = "0"+str(day)
    try:
        return sorted_words_dict[pendulum.parse(str(year)+"-"+str(month)+"-"+str(day)).format("YYYY-MM-DD")]
    except:
        return "No wordle for that date!"

print(get_wordle_date(year=2022, month=4, day=28))
# Out:
# zesty

# %% [markdown]
# # 3. Proper Solution

# %% [markdown]
# We will solve Wordle using an algorithm which takes in feedback like a human and makes smart guesses!

# %% [markdown]
# ## FAILED ATTEMPT! :

# %%
# FAILED ATTEMPT!

class WordleSolver():
    def __init__(self, possible_words):
        self.possible_words = possible_words
        pass

    def letter_values(self, result, guess):
        """Finds values of each letter"""
        result_outcome = []
        for i in range(0, 5):
            if result[i] == "b":
                result_outcome.append([guess[i], "b"])
            elif result[i] == "y":
                result_outcome.append([guess[i], "y"])
            elif result[i] == "g":
                result_outcome.append([guess[i], "g"])
        return result_outcome

    
    def word_remover(self, result, guess):
        """Returns the list of words with incorrect possibilties removed"""
        usable_words = []
        c = 0
        for item in self.letter_values(result, guess):
            if item[1] == "b":
                for word in self.possible_words:
                    if item[0] not in word:
                        usable_words.append(word)
            elif item[1] == "y":
                for word in self.possible_words:
                    if item[0] not in word[c]:
                        usable_words.append(word)
            elif item[1] == "g":
                for word in self.possible_words:
                    if item[0] in word[c]:
                        usable_words.append(word) 
            c+=1
        
        return usable_words
    

    def letterFreq(self):
        """Finds frequencies of letters in each position"""
        alphabet = "abcdefghijklmnopqrstuvwxyz"
        arr = {}
        for c in alphabet:
            freq = [0, 0, 0, 0, 0]
            for i in range(0, 5):
                for w in self.possible_words:
                    if w[i] == c:
                        freq[i] += 1
            arr.update({c: freq})
        return arr
    
    def wordScore(self, frequencies):
        """Computes a score based off letter frequencies"""
        words = {}
        max_freq = [0, 0, 0, 0, 0]
        for c in frequencies:
            for i in range(0, 5):
                if max_freq[i] < frequencies[c][i]:
                    max_freq[i] = frequencies[c][i]
        for w in self.possible_words:
            score = 1
            for i in range(0, 5):
                c = w[i]
                score *= 1 + (frequencies[c][i] - max_freq[i]) ** 2
            words.update({w: score})
        return words
    
    def bestWord(self, frequencies):
        """Finds the best word"""
        max_score = 1000000000000000000     # start with a ridiculous score
        best_word = "words"     # start with a random word
        scores = self.wordScore(frequencies)
        for w in self.possible_words:
            if scores[w] < max_score:
                max_score = scores[w]
                best_word = w
        return best_word
    
    def wordleSolver(self):
        """Prompts you to solve Wordle"""
        print("Welcome to the Wordle Solver!")
        print("The suggested starting word is:", self.bestWord(self.letterFreq()))
        guess = self.bestWord(self.letterFreq())
        print("Enter your first result:")
        result = input()
        counter = 1
        while result != "ggggg" and counter < 6:
            self.possible_words = self.word_remover(result, guess)
            print(self.possible_words)
            if len(self.possible_words) == 0:
                break
            suggestion = self.bestWord(self.letterFreq())
            print("The suggested word is:", suggestion)
            guess = suggestion
            print("Enter your new result:")
            result = input()
            counter += 1
        if counter == 6 and result != "ggggg":
            print("Number of guesses exceeded, sorry we failed!")
        else:
            print("Congratulations! We solved today's Wordle in", counter, "guesses.")

# %% [markdown]
# ## SUCCESSFUL ATTEMPT! :

# %%
# FINALLY WORKS!

def badLetters(result, guess):
    """Finds incorrect letters in word"""
    bad_letters = []
    for i in range(0, 5):
        if result[i] == "b":
            bad_letters.append(guess[i])
    return bad_letters

def partialLetters(result, guess):
    """Finds correct letters that are misplaced in word"""
    partial_letters = []
    for i in range(0, 5):
        if result[i] == "y":
            partial_letters.append([guess[i], i])
    return partial_letters

def correctLetters(result, guess):
    """Finds fully correct letters in word"""
    correct_letters = []
    for i in range(0, 5):
        if result[i] == "g":
            correct_letters.append([guess[i], i])
    return correct_letters

def word_remover(result, guess, possible_words):
    """Returns the list of words with incorrect possibilties removed"""
    bad_letters = badLetters(result, guess)
    correct_letters = correctLetters(result, guess)
    partial_letters = partialLetters(result, guess)
    good_letters = []
    for g in correct_letters:
        good_letters.append(g[0])
    for p in partial_letters:
        good_letters.append(p[0])
    
    acceptable_words1 = []
    for w in possible_words:
        check = 0
        for b in bad_letters:
            if b in w:
                if b in good_letters:
                    pass
                else:
                    check = 1
                    break
        if check == 0:
            acceptable_words1.append(w)

    acceptable_words2 = []
    for w in acceptable_words1:
        check = 0
        for g in correct_letters:
            if w[g[1]] != g[0]:
                check = 1
                break
        if check == 0:
            acceptable_words2.append(w)
    
    acceptable_words3 = []
    for w in acceptable_words2:
        check = 0
        for p in partial_letters:
            if w[p[1]] == p[0]:
                check = 1
                break
        if check == 0:
            acceptable_words3.append(w)
    
    acceptable_words4 = []
    for w in acceptable_words3:
        check = 0
        for g in good_letters:
            if g not in w:
                check = 1
                break
        if check == 0:
            acceptable_words4.append(w)

    acceptable_words5 = []
    for w in acceptable_words4:
        check = 0
        for b in bad_letters:
            if b in good_letters:
                if w.count(b) != good_letters.count(b):
                    check = 1
                    break
        if check == 0:
            acceptable_words5.append(w)
    
    return acceptable_words5

def letterFreq(possible_words):
    """Finds frequencies of letters in each position"""
    alphabet = "abcdefghijklmnopqrstuvwxyz"
    arr = {}
    for c in alphabet:
        freq = [0, 0, 0, 0, 0]
        for i in range(0, 5):
            for w in possible_words:
                if w[i] == c:
                    freq[i] += 1
        arr.update({c: freq})
    return arr

def wordScore(possible_words, frequencies):
    """Computes a score based off letter frequencies"""
    words = {}
    max_freq = [0, 0, 0, 0, 0]
    for c in frequencies:
        for i in range(0, 5):
            if max_freq[i] < frequencies[c][i]:
                max_freq[i] = frequencies[c][i]
    for w in possible_words:
        score = 1
        for i in range(0, 5):
            c = w[i]
            score *= 1 + (frequencies[c][i] - max_freq[i]) ** 2
        words.update({w: score})
    return words

def bestWord(possible_words, frequencies):
    """Finds the best word"""
    max_score = 1000000000000000000     # start with a ridiculous score
    best_word = "words"     # start with a random word
    scores = wordScore(possible_words, frequencies)
    for w in possible_words:
        if scores[w] < max_score:
            max_score = scores[w]
            best_word = w
    return best_word

def wordleSolver(possible_words):
    """Prompts you to solve Wordle"""
    print("Welcome to the Wordle Solver!")
    first_suggestion = bestWord(possible_words, letterFreq(possible_words))
    print("The suggested starting word is:", first_suggestion)
    guess = first_suggestion
    print("Enter your first result:")
    result = input()
    counter = 1
    while result != "ggggg" and counter < 6:
        possible_words = word_remover(result, guess, possible_words)
        print(possible_words)
        if len(possible_words) == 0:
            break
        suggestion = bestWord(possible_words, letterFreq(possible_words))
        print("The suggested word is:", suggestion)
        guess = suggestion
        print("Enter your new result:")
        result = input()
        counter += 1
    if len(possible_words) == 0:
        print("Oh no! You made a mistake entering one of your results. Please try again.")
    elif counter == 6 and result != "ggggg":
        print("Number of guesses exceeded, sorry we failed!")
    else:
        print("Congratulations! We solved today's Wordle in", counter, "guesses.")

# %%
wordleSolver(word_list)
# Out:
# Welcome to the Wordle Solver!
# The suggested starting word is: slate
# Enter your first result:
# ['sissy', 'shrub', 'spicy', 'sonic', 'shown', 'scour', 'showy', 'shrug', 'soggy', 'scorn', 'shock', 'skimp', 'sunny', 'sorry', 'snuck', 'spiny', 'sushi', 'scion', 'shook', 'sound', 'sworn', 'scrub', 'swoon', 'snuff', 'snoop', 'suing', 'shirk', 'spurn', 'swish', 'shuck', 'skunk', 'smock', 'synod', 'syrup', 'swung', 'spunk', 'smoky', 'shush', 'smirk', 'shiny', 'sword', 'spoof', 'squib', 'spoon', 'skiff', 'scoop', 'swing', 'scoff', 'swoop', 'scrum', 'sprig', 'sniff', 'spiky', 'spook', 'shorn', 'snowy']
# The suggested word is: shook
# Enter your new result:
# ['shown', 'showy', 'shorn']
# The suggested word is: shown
# Enter your new result:
# Congratulations! We solved today's Wordle in 3 guesses.

# %% [markdown]
# **Works Great!**

# %% [markdown]
# # 4.Testing Average Guesses

# %% [markdown]
# Since we now have an algorithm that can solve wordle, lets try to see how mnay guesses it requires on average to get the word right. We will try all the word in our words list and test the bot against them.
#
# We will need to make small changes to our bot to enable the automatic testing:

# %%
def get_tries(possible_words, word_to_guess):
    """Prompts you to solve Wordle"""
    first_suggestion = bestWord(possible_words, letterFreq(possible_words))
    guess = first_suggestion
    print(guess)
    def get_letter_colors(actual, guess):
        # There are three possible conditions for every letter in the guess word:
        # Correct letter, correct position (green)
        # Correct letter, incorrect position (orange)
        # Incorrect letter (red)
        letterColors = []
        
        actualLetterCounts = {}
        for letter in actual:
            if letter not in actualLetterCounts:
                actualLetterCounts[letter] = 1
            else:
                actualLetterCounts[letter] += 1

        guessLetterCounts = {}        
        for letter in guess:
            if letter not in guessLetterCounts:
                guessLetterCounts[letter] = 1
            else:
                guessLetterCounts[letter] += 1

        for letterIndex in range(0, 5):
            if guess[letterIndex] == actual[letterIndex]:
                letterColors.append((guess[letterIndex], 'g'))
        # Only this one condition can lead to the duplicate problem.
        # So, instead of just checking whether the letter is in the word,
        # we have to check how many of it are in the guess versus how many
        # of it are in the actual word.  If it's in the wrong place and the
        # count is higher in guess than actual, it is a wrong letter:
        # color it red.  Otherwise, it's correct but misplaced:  color it orange.
            elif guess[letterIndex] in actual:
                if guessLetterCounts[guess[letterIndex]] > actualLetterCounts[guess[letterIndex]]:
                    letterColors.append((guess[letterIndex], 'b'))
                    # Decrement the count once the superfluous letter has been labeled incorrect
                    guessLetterCounts[guess[letterIndex]] -= 1
                else:
                    letterColors.append((guess[letterIndex], 'y'))
            else:
                letterColors.append((guess[letterIndex], 'b'))
        return letterColors

    result = get_letter_colors(word_to_guess, guess)
    result_str = ""
    for x in result:
        result_str += x[1]
    result = result_str

    counter = 1
    while result != "ggggg" and counter < 6:
        possible_words = word_remover(result, guess, possible_words)
        print(possible_words)
        if len(possible_words) == 0:
            break
        suggestion = bestWord(possible_words, letterFreq(possible_words))
        guess = suggestion
        result = get_letter_colors(word_to_guess, guess)
        result_str = ""
        for x in result:
            result_str += x[1]
        result = result_str


        counter += 1
    if counter == 6 and result != "ggggg":
        return -1
    else:
        return counter

# %%
tries = []
for word in word_list:
    tries.append(get_tries(word_list, word))
# Out:
# slate
# ['cigar', 'karma', 'major', 'marry', 'croak', 'maxim', 'parry', 'gamma', 'briar', 'gaudy', 'vodka', 'radio', 'favor', 'panic', 'aroma', 'comma', 'foray', 'cargo', 'hairy', 'canny', 'bayou', 'manor', 'apron', 'cacao', 'gawky', 'madam', 'augur', 'wacky', 'angry', 'aphid', 'dandy', 'carry', 'rainy', 'daddy', 'aging', 'mocha', 'pagan', 'human', 'manga', 'groan', 'fairy', 'ardor', 'nanny', 'handy', 'ninja', 'vapor', 'acorn', 'aping', 'mania', 'borax', 'china', 'rabid', 'caddy', 'magic', 'macaw', 'candy', 'march', 'arbor', 'hardy', 'razor', 'wagon', 'cabin', 'fancy', 'friar', 'dairy', 'among', 'rabbi', 'agony', 'urban', 'rajah', 'gonad', 'adorn', 'mafia', 'array', 'vapid', 'acrid', 'mayor', 'randy', 'radar', 'canon', 'pizza', 'baggy', 'mammy', 'nadir', 'havoc', 'annoy', 'kappa', 'bawdy', 'radii', 'dogma', 'nomad', 'cocoa', 'mango', 'rumba', 'audio', 'manic', 'admin', 'macho', 'harpy', 'cairn', 'broad', 'axiom', 'armor', 'jazzy', 'arrow', 'vicar', 'cobra', 'macro', 'baron', 'bacon', 'umbra', 'avian', 'parka', 'avoid', 'circa', 'paddy', 'mambo', 'affix', 'abhor', 'kayak', 'banjo', 'axion', 'ranch', 'mamma', 'cabby', 'magma', 'woman', 'rapid', 'fauna', 'happy', 'mangy', 'organ', 'rayon', 'harry', 'fanny']
# ['cigar', 'augur']
# slate
# ['rebut', 'quiet', 'unmet', 'totem', 'greet', 'tweed', 'comet', 'retch', 'tiger', 'other', 'their', 'depot', 'inert', 'crept', 'retro', 'egret', 'merit', 'inter', 'inept', 'threw', 'recut', 'deter', 'rivet', 'covet', 'octet', 'erupt', 'tenet', 'edict', 'fetid', 'often', 'eight', 'event', 'outer', 'evict', 'enter', 'otter', 'tuber', 'overt', 'ether', 'timer', 'beget', 'tempo', 'debit', 'remit', 'fetch', 'thief', 'tweet', 'duvet', 'detox', 'retry', 'utter', 'debut', 'ethic', 'befit', 'token', 'entry', 'voter', 'tried', 'tenor', 'trend', 'tower', 'truer', 'erect', 'beret', 'exert', 'metro', 'theft', 'meter', 'teddy', 'tepid', 'eject', 'refit']
# ['rebut', 'depot', 'merit', 'recut', 'debit', 'remit', 'debut', 'befit', 'refit']
# ['rebut']
# slate
# ['awake', 'evade', 'grade', 'brake', 'craze', 'frame', 'agape', 'grave', 'inane', 'crave', 'grace', 'weave', 'amaze', 'grape', 'brave', 'graze', 'adage', 'aware', 'knave', 'chafe', 'drake', 'quake', 'crane', 'heave', 'drape', 'brace', 'image', 'peace']
# ['awake', 'inane', 'amaze', 'chafe', 'quake', 'peace']
# slate
# ['blush', 'floss', 'plush', 'bliss', 'gloss', 'flush']
# slate
# ['focal', 'naval', 'offal', 'labor', 'badly', 'viral', 'banal', 'caulk', 'royal', 'larva', 'awful', 'lilac', 'valid', 'final', 'valor', 'annul', 'lunar', 'inlay', 'lanky', 'amply', 'molar', 'gayly', 'dally', 'vocal', 'laugh', 'cavil', 'villa', 'viola', 'local', 'modal', 'coral', 'apply', 'bylaw', 'loyal', 'afoul', 'aglow', 'carol', 'canal', 'polar', 'balmy', 'mural', 'moral', 'voila', 'axial', 'daily', 'papal', 'rally', 'cabal', 'ralph', 'zonal', 'anvil', 'madly', 'manly', 'polka', 'rival', 'rural', 'gaily']
# ['focal', 'vocal', 'local']
# slate
# ['awake', 'evade', 'grade', 'brake', 'craze', 'frame', 'agape', 'grave', 'inane', 'crave', 'grace', 'weave', 'amaze', 'grape', 'brave', 'graze', 'adage', 'aware', 'knave', 'chafe', 'drake', 'quake', 'crane', 'heave', 'drape', 'brace', 'image', 'peace']
# ['evade']
# slate
# ['focal', 'naval', 'offal', 'labor', 'badly', 'viral', 'banal', 'caulk', 'royal', 'larva', 'awful', 'lilac', 'valid', 'final', 'valor', 'annul', 'lunar', 'inlay', 'lanky', 'amply', 'molar', 'gayly', 'dally', 'vocal', 'laugh', 'cavil', 'villa', 'viola', 'local', 'modal', 'coral', 'apply', 'bylaw', 'loyal', 'afoul', 'aglow', 'carol', 'canal', 'polar', 'balmy', 'mural', 'moral', 'voila', 'axial', 'daily', 'papal', 'rally', 'cabal', 'ralph', 'zonal', 'anvil', 'madly', 'manly', 'polka', 'rival', 'rural', 'gaily']
# ['naval']
# slate
# ['serve', 'spike', 'siege', 'shire', 'smoke', 'swine', 'singe', 'swore', 'score', 'scope', 'since', 'spoke', 'seize', 'sieve', 'spore', 'snide', 'shove', 'spire', 'segue', 'scone', 'spice', 'shone', 'spree', 'sense', 'spine', 'snipe', 'surge', 'shore', 'scene', 'scree', 'snore', 'shine']
# ['serve', 'surge', 'scree']
# slate
# ['heath', 'death', 'meaty']
# slate
# ['dwarf', 'crazy', 'drain', 'aback', 'champ', 'crank', 'whack', 'hoard', 'cramp', 'khaki', 'charm', 'wharf', 'coach', 'award', 'chaff', 'brawn', 'ovary', 'brain', 'bravo', 'braid', 'roach', 'diary', 'drank', 'piano', 'prank', 'quack', 'gravy', 'chair', 'quark', 'again', 'knack', 'wrack', 'fraud', 'drawn', 'chard', 'graph', 'foamy', 'brand', 'drama', 'prawn', 'board', 'grain', 'frank', 'grand', 'chain', 'crack', 'guava', 'guard']
# ['dwarf', 'hoard', 'wharf', 'award', 'ovary', 'diary', 'board', 'guard']
# ['dwarf', 'diary']
# slate
# ['rebut', 'quiet', 'unmet', 'totem', 'greet', 'tweed', 'comet', 'retch', 'tiger', 'other', 'their', 'depot', 'inert', 'crept', 'retro', 'egret', 'merit', 'inter', 'inept', 'threw', 'recut', 'deter', 'rivet', 'covet', 'octet', 'erupt', 'tenet', 'edict', 'fetid', 'often', 'eight', 'event', 'outer', 'evict', 'enter', 'otter', 'tuber', 'overt', 'ether', 'timer', 'beget', 'tempo', 'debit', 'remit', 'fetch', 'thief', 'tweet', 'duvet', 'detox', 'retry', 'utter', 'debut', 'ethic', 'befit', 'token', 'entry', 'voter', 'tried', 'tenor', 'trend', 'tower', 'truer', 'erect', 'beret', 'exert', 'metro', 'theft', 'meter', 'teddy', 'tepid', 'eject', 'refit']
# ['quiet', 'comet', 'rivet', 'covet', 'duvet']
# ['quiet']
# slate
# ['bench', 'feign', 'unfed', 'error', 'wooer', 'goner', 'hyper', 'dozen', 'fixer', 'heron', 'finer', 'perch', 'epoch', 'ferry', 'query', 'perky', 'renew', 'epoxy', 'fewer', 'cheek', 'foyer', 'homer', 'being', 'money', 'power', 'poker', 'woven', 'needy', 'ruder', 'chief', 'enjoy', 'denim', 'piney', 'equip', 'udder', 'given', 'honey', 'derby', 'diner', 'creek', 'embed', 'edify', 'queer', 'venom', 'freer', 'nicer', 'pried', 'index', 'fiber', 'ennui', 'river', 'begun', 'rover', 'woken', 'wreck', 'cover', 'beech', 'joker', 'diver', 'creed', 'vixen', 'geeky', 'check', 'demur', 'queen', 'every', 'inner', 'reign', 'grief', 'creep', 'buyer', 'cyber', 'offer', 'dryer', 'infer', 'credo', 'boxer', 'giver', 'preen', 'wider', 'breed', 'deign', 'fiend', 'envoy', 'brief', 'never', 'fiery', 'cider', 'owner', 'ember', 'recur', 'hover', 'jerky', 'beefy', 'upper', 'mover', 'defer', 'crier', 'drier', 'nerdy', 'hymen', 'freed', 'enemy', 'decor', 'piper', 'riper', 'unwed', 'weedy', 'order', 'widen', 'demon', 'begin', 'under', 'refer', 'rerun', 'cheer', 'miner', 'green', 'covey', 'viper', 'ebony', 'neigh', 'kneed', 'decoy', 'odder', 'weird', 'weigh', 'dicey', 'bicep', 'fever', 'debug', 'video', 'medic', 'women', 'coven', 'purer', 'merry', 'berry', 'cower', 'penny', 'modem', 'greed', 'reedy', 'corer', 'fried', 'boney', 'endow', 'mower', 'gooey', 'eking', 'newer', 'dopey', 'cried', 'dried', 'rider', 'femur', 'decry', 'eying', 'ripen', 'gecko', 'rodeo', 'mercy', 'roger', 'rower']
# ['bench', 'being', 'venom', 'begun', 'begin', 'neigh', 'weigh', 'penny', 'gecko']
# slate
# ['abate', 'crate', 'agate', 'grate', 'irate', 'ovate']
# ['abate', 'agate', 'ovate']
# slate
# ['bench', 'feign', 'unfed', 'error', 'wooer', 'goner', 'hyper', 'dozen', 'fixer', 'heron', 'finer', 'perch', 'epoch', 'ferry', 'query', 'perky', 'renew', 'epoxy', 'fewer', 'cheek', 'foyer', 'homer', 'being', 'money', 'power', 'poker', 'woven', 'needy', 'ruder', 'chief', 'enjoy', 'denim', 'piney', 'equip', 'udder', 'given', 'honey', 'derby', 'diner', 'creek', 'embed', 'edify', 'queer', 'venom', 'freer', 'nicer', 'pried', 'index', 'fiber', 'ennui', 'river', 'begun', 'rover', 'woken', 'wreck', 'cover', 'beech', 'joker', 'diver', 'creed', 'vixen', 'geeky', 'check', 'demur', 'queen', 'every', 'inner', 'reign', 'grief', 'creep', 'buyer', 'cyber', 'offer', 'dryer', 'infer', 'credo', 'boxer', 'giver', 'preen', 'wider', 'breed', 'deign', 'fiend', 'envoy', 'brief', 'never', 'fiery', 'cider', 'owner', 'ember', 'recur', 'hover', 'jerky', 'beefy', 'upper', 'mover', 'defer', 'crier', 'drier', 'nerdy', 'hymen', 'freed', 'enemy', 'decor', 'piper', 'riper', 'unwed', 'weedy', 'order', 'widen', 'demon', 'begin', 'under', 'refer', 'rerun', 'cheer', 'miner', 'green', 'covey', 'viper', 'ebony', 'neigh', 'kneed', 'decoy', 'odder', 'weird', 'weigh', 'dicey', 'bicep', 'fever', 'debug', 'video', 'medic', 'women', 'coven', 'purer', 'merry', 'berry', 'cower', 'penny', 'modem', 'greed', 'reedy', 'corer', 'fried', 'boney', 'endow', 'mower', 'gooey', 'eking', 'newer', 'dopey', 'cried', 'dried', 'rider', 'femur', 'decry', 'eying', 'ripen', 'gecko', 'rodeo', 'mercy', 'roger', 'rower']
# ['feign']
# slate
# ['cigar', 'karma', 'major', 'marry', 'croak', 'maxim', 'parry', 'gamma', 'briar', 'gaudy', 'vodka', 'radio', 'favor', 'panic', 'aroma', 'comma', 'foray', 'cargo', 'hairy', 'canny', 'bayou', 'manor', 'apron', 'cacao', 'gawky', 'madam', 'augur', 'wacky', 'angry', 'aphid', 'dandy', 'carry', 'rainy', 'daddy', 'aging', 'mocha', 'pagan', 'human', 'manga', 'groan', 'fairy', 'ardor', 'nanny', 'handy', 'ninja', 'vapor', 'acorn', 'aping', 'mania', 'borax', 'china', 'rabid', 'caddy', 'magic', 'macaw', 'candy', 'march', 'arbor', 'hardy', 'razor', 'wagon', 'cabin', 'fancy', 'friar', 'dairy', 'among', 'rabbi', 'agony', 'urban', 'rajah', 'gonad', 'adorn', 'mafia', 'array', 'vapid', 'acrid', 'mayor', 'randy', 'radar', 'canon', 'pizza', 'baggy', 'mammy', 'nadir', 'havoc', 'annoy', 'kappa', 'bawdy', 'radii', 'dogma', 'nomad', 'cocoa', 'mango', 'rumba', 'audio', 'manic', 'admin', 'macho', 'harpy', 'cairn', 'broad', 'axiom', 'armor', 'jazzy', 'arrow', 'vicar', 'cobra', 'macro', 'baron', 'bacon', 'umbra', 'avian', 'parka', 'avoid', 'circa', 'paddy', 'mambo', 'affix', 'abhor', 'kayak', 'banjo', 'axion', 'ranch', 'mamma', 'cabby', 'magma', 'woman', 'rapid', 'fauna', 'happy', 'mangy', 'organ', 'rayon', 'harry', 'fanny']
# ['major', 'maxim', 'madam', 'macaw', 'march', 'mafia', 'macho', 'macro', 'mambo', 'mamma']
# ['major']
# slate
# ['heath', 'death', 'meaty']
# ['death']
# slate
# ['fresh', 'usher', 'rebus', 'risen', 'cress', 'poser', 'poesy', 'pesky', 'resin', 'guess', 'dress', 'nosey', 'bused', 'miser', 'chess', 'verso', 'wiser', 'press', 'riser']
# ['marry', 'mammy']
# slate
# ['react', 'heart', 'meant', 'enact', 'teary', 'teach', 'exact']
# slate
# ['batty', 'patty', 'tatty', 'aunty', 'quota', 'fatty', 'party', 'amity', 'warty', 'cacti', 'ratty', 'junta', 'faith', 'catty', 'aorta']
# ['batty', 'tatty', 'fatty', 'ratty', 'catty']
# slate
# ['pride', 'bribe', 'biome', 'forge', 'erode', 'gouge', 'rogue', 'rouge', 'prove', 'grime', 'gripe', 'gorge', 'wince', 'dodge', 'choke', 'rupee', 'brine', 'movie', 'purge', 'mince', 'oxide', 'hinge', 'voice', 'wedge', 'midge', 'rhyme', 'prize', 'booze', 'grove', 'pique', 'genre', 'undue', 'eerie', 'price', 'niece', 'diode', 'prone', 'evoke', 'nerve', 'ridge', 'gnome', 'budge', 'ozone', 'queue', 'verve', 'genie', 'dunce', 'prime', 'nudge', 'knife', 'where', 'emcee', 'puree', 'venue', 'pixie', 'penne', 'drove', 'chore', 'grope', 'dirge', 'horde', 'pence', 'creme', 'merge', 'urine', 'fugue', 'bride', 'prude', 'femme', 'probe', 'crepe', 'force', 'verge', 'guide', 'revue', 'crude', 'opine', 'prune', 'vogue', 'chide', 'broke', 'phone', 'binge', 'fence', 'ounce', 'crime', 'imbue', 'drone', 'niche', 'juice', 'ovine', 'borne', 'deuce', 'hedge', 'coupe', 'froze', 'chime', 'curve', 'drive', 'fudge', 'whine', 'crone', 'hence', 'piece', 'judge', 'ombre']
# ['pride', 'prize', 'prime']
# slate
# ['blush', 'floss', 'plush', 'bliss', 'gloss', 'flush']
# ['floss', 'gloss']
# slate
# ['model', 'helix', 'whelp', 'linen', 'belly', 'golem', 'belch', 'yield', 'field', 'liver', 'gruel', 'leery', 'libel', 'lover', 'reply', 'dowel', 'bowel', 'vowel', 'kneel', 'quell', 'hovel', 'ruler', 'excel', 'level', 'jelly', 'lower', 'idler', 'wheel', 'dwell', 'rebel', 'bevel', 'lemur', 'novel', 'below', 'cruel', 'jewel', 'wield', 'pixel', 'liner', 'melon', 'leper', 'expel', 'revel', 'cello', 'leggy', 'devil', 'liken', 'lumen', 'welch', 'leech', 'bezel', 'filer', 'lemon', 'lever', 'repel', 'newly', 'relic', 'felon', 'impel', 'peril', 'hello']
# ['helix', 'belch', 'reply', 'lemur', 'below', 'melon', 'leggy', 'welch', 'lemon', 'newly', 'relic', 'felon']
# ['helix', 'belch', 'welch', 'relic']
# ['helix']
# slate
# ['cigar', 'karma', 'major', 'marry', 'croak', 'maxim', 'parry', 'gamma', 'briar', 'gaudy', 'vodka', 'radio', 'favor', 'panic', 'aroma', 'comma', 'foray', 'cargo', 'hairy', 'canny', 'bayou', 'manor', 'apron', 'cacao', 'gawky', 'madam', 'augur', 'wacky', 'angry', 'aphid', 'dandy', 'carry', 'rainy', 'daddy', 'aging', 'mocha', 'pagan', 'human', 'manga', 'groan', 'fairy', 'ardor', 'nanny', 'handy', 'ninja', 'vapor', 'acorn', 'aping', 'mania', 'borax', 'china', 'rabid', 'caddy', 'magic', 'macaw', 'candy', 'march', 'arbor', 'hardy', 'razor', 'wagon', 'cabin', 'fancy', 'friar', 'dairy', 'among', 'rabbi', 'agony', 'urban', 'rajah', 'gonad', 'adorn', 'mafia', 'array', 'vapid', 'acrid', 'mayor', 'randy', 'radar', 'canon', 'pizza', 'baggy', 'mammy', 'nadir', 'havoc', 'annoy', 'kappa', 'bawdy', 'radii', 'dogma', 'nomad', 'cocoa', 'mango', 'rumba', 'audio', 'manic', 'admin', 'macho', 'harpy', 'cairn', 'broad', 'axiom', 'armor', 'jazzy', 'arrow', 'vicar', 'cobra', 'macro', 'baron', 'bacon', 'umbra', 'avian', 'parka', 'avoid', 'circa', 'paddy', 'mambo', 'affix', 'abhor', 'kayak', 'banjo', 'axion', 'ranch', 'mamma', 'cabby', 'magma', 'woman', 'rapid', 'fauna', 'happy', 'mangy', 'organ', 'rayon', 'harry', 'fanny']
# ['croak', 'briar', 'vodka', 'aphid', 'ardor', 'borax', 'arbor', 'friar', 'acrid', 'pizza', 'cocoa', 'audio', 'broad', 'arrow', 'vicar', 'cobra', 'avoid', 'circa', 'affix', 'abhor']
# ['croak']
# slate
# ['staff', 'stand', 'start', 'smart', 'stair', 'stack', 'stank', 'stamp', 'shaft', 'stain', 'scant', 'stark', 'stash', 'staid']
# ['staff', 'stand', 'stack', 'stank', 'stamp', 'stain', 'stash', 'staid']
# ['staff', 'stack', 'stamp', 'stash']
# slate
# ['paper', 'repay', 'kebab', 'enema', 'break', 'abbey', 'ahead', 'gamer', 'creak', 'parer', 'recap', 'dream', 'baker', 'cream', 'decay', 'rebar', 'rehab', 'zebra', 'aider', 'ocean', 'haven', 'harem', 'arena', 'bread', 'freak', 'amend', 'ramen', 'caper', 'wager', 'oaken', 'racer', 'cedar', 'cheap', 'media', 'dread', 'waxen', 'gazer', 'annex', 'omega', 'cameo', 'debar', 'maker', 'began', 'eager', 'hyena', 'rarer', 'waver', 'wafer', 'wreak', 'apnea', 'gayer', 'opera', 'amber', 'cagey', 'pecan', 'raven', 'vegan', 'knead', 'anger', 'mecca', 'payer']
# ['paper', 'gamer', 'baker', 'wager', 'gazer', 'maker', 'eager', 'waver', 'wafer', 'gayer', 'payer']
# ['paper', 'baker', 'maker', 'payer']
# slate
# ['bench', 'feign', 'unfed', 'error', 'wooer', 'goner', 'hyper', 'dozen', 'fixer', 'heron', 'finer', 'perch', 'epoch', 'ferry', 'query', 'perky', 'renew', 'epoxy', 'fewer', 'cheek', 'foyer', 'homer', 'being', 'money', 'power', 'poker', 'woven', 'needy', 'ruder', 'chief', 'enjoy', 'denim', 'piney', 'equip', 'udder', 'given', 'honey', 'derby', 'diner', 'creek', 'embed', 'edify', 'queer', 'venom', 'freer', 'nicer', 'pried', 'index', 'fiber', 'ennui', 'river', 'begun', 'rover', 'woken', 'wreck', 'cover', 'beech', 'joker', 'diver', 'creed', 'vixen', 'geeky', 'check', 'demur', 'queen', 'every', 'inner', 'reign', 'grief', 'creep', 'buyer', 'cyber', 'offer', 'dryer', 'infer', 'credo', 'boxer', 'giver', 'preen', 'wider', 'breed', 'deign', 'fiend', 'envoy', 'brief', 'never', 'fiery', 'cider', 'owner', 'ember', 'recur', 'hover', 'jerky', 'beefy', 'upper', 'mover', 'defer', 'crier', 'drier', 'nerdy', 'hymen', 'freed', 'enemy', 'decor', 'piper', 'riper', 'unwed', 'weedy', 'order', 'widen', 'demon', 'begin', 'under', 'refer', 'rerun', 'cheer', 'miner', 'green', 'covey', 'viper', 'ebony', 'neigh', 'kneed', 'decoy', 'odder', 'weird', 'weigh', 'dicey', 'bicep', 'fever', 'debug', 'video', 'medic', 'women', 'coven', 'purer', 'merry', 'berry', 'cower', 'penny', 'modem', 'greed', 'reedy', 'corer', 'fried', 'boney', 'endow', 'mower', 'gooey', 'eking', 'newer', 'dopey', 'cried', 'dried', 'rider', 'femur', 'decry', 'eying', 'ripen', 'gecko', 'rodeo', 'mercy', 'roger', 'rower']
# ['unfed']
# slate
# ['model', 'helix', 'whelp', 'linen', 'belly', 'golem', 'belch', 'yield', 'field', 'liver', 'gruel', 'leery', 'libel', 'lover', 'reply', 'dowel', 'bowel', 'vowel', 'kneel', 'quell', 'hovel', 'ruler', 'excel', 'level', 'jelly', 'lower', 'idler', 'wheel', 'dwell', 'rebel', 'bevel', 'lemur', 'novel', 'below', 'cruel', 'jewel', 'wield', 'pixel', 'liner', 'melon', 'leper', 'expel', 'revel', 'cello', 'leggy', 'devil', 'liken', 'lumen', 'welch', 'leech', 'bezel', 'filer', 'lemon', 'lever', 'repel', 'newly', 'relic', 'felon', 'impel', 'peril', 'hello']
# ['helix', 'whelp', 'belch', 'yield', 'field', 'reply', 'lemur', 'below', 'wield', 'melon', 'leggy', 'welch', 'lemon', 'newly', 'relic', 'felon']
# ['whelp', 'yield', 'wield']
# ['whelp']
# slate
# ['trawl', 'trail']
# slate
# ['outdo', 'digit', 'print', 'front', 'motor', 'thumb', 'ought', 'dutch', 'pithy', 'point', 'robot', 'mount', 'thorn', 'butch', 'input', 'hutch', 'night', 'unfit', 'doubt', 'count', 'tough', 'idiot', 'might', 'toxin', 'tunic', 'thump', 'outgo', 'burnt', 'pitch', 'trout', 'donut', 'third', 'trick', 'tutor', 'grunt', 'touch', 'notch', 'hitch', 'motif', 'crypt', 'trunk', 'wight', 'optic', 'grout', 'torch', 'tying', 'joint', 'orbit', 'thick', 'ingot', 'throw', 'pivot', 'troop', 'botch', 'itchy', 'topic', 'uncut', 'ditch', 'toxic', 'think', 'court', 'throb', 'drift', 'fight', 'toddy', 'tumor', 'tonic', 'trump', 'thigh', 'fruit', 'right', 'brunt', 'tight', 'droit', 'truck', 'thing', 'timid', 'rotor', 'witch', 'thong', 'thrum', 'turbo', 'bigot', 'intro', 'twixt', 'vomit']
# ['outdo', 'outgo', 'grout']
# slate
# ['adobe', 'agree', 'argue', 'badge', 'farce', 'gauze', 'canoe', 'carve', 'awoke', 'range', 'barge', 'azure', 'anime', 'waive', 'naive', 'abide', 'adore', 'mange', 'gaffe', 'cache', 'afire', 'maize', 'dance', 'abode', 'maybe', 'above', 'anode', 'vague', 'mauve', 'payee', 'gauge']
# ['adobe', 'agree', 'argue', 'azure', 'adore', 'abode', 'anode']
# ['adobe']
# slate
# ['dwarf', 'crazy', 'drain', 'aback', 'champ', 'crank', 'whack', 'hoard', 'cramp', 'khaki', 'charm', 'wharf', 'coach', 'award', 'chaff', 'brawn', 'ovary', 'brain', 'bravo', 'braid', 'roach', 'diary', 'drank', 'piano', 'prank', 'quack', 'gravy', 'chair', 'quark', 'again', 'knack', 'wrack', 'fraud', 'drawn', 'chard', 'graph', 'foamy', 'brand', 'drama', 'prawn', 'board', 'grain', 'frank', 'grand', 'chain', 'crack', 'guava', 'guard']
# ['crazy', 'cramp']
# slate
# ['sower', 'seedy', 'spend', 'surer', 'sever', 'sheen', 'siren', 'sweep', 'shied', 'speck', 'sheik', 'seven', 'serum', 'sneer', 'super', 'speed', 'shrew', 'sober', 'semen', 'screw', 'sewer', 'sperm', 'sheer', 'sinew', 'skier', 'sheep', 'serif', 'spied']
# ['sower', 'surer', 'super', 'sober', 'skier']
# slate
# ['paper', 'repay', 'kebab', 'enema', 'break', 'abbey', 'ahead', 'gamer', 'creak', 'parer', 'recap', 'dream', 'baker', 'cream', 'decay', 'rebar', 'rehab', 'zebra', 'aider', 'ocean', 'haven', 'harem', 'arena', 'bread', 'freak', 'amend', 'ramen', 'caper', 'wager', 'oaken', 'racer', 'cedar', 'cheap', 'media', 'dread', 'waxen', 'gazer', 'annex', 'omega', 'cameo', 'debar', 'maker', 'began', 'eager', 'hyena', 'rarer', 'waver', 'wafer', 'wreak', 'apnea', 'gayer', 'opera', 'amber', 'cagey', 'pecan', 'raven', 'vegan', 'knead', 'anger', 'mecca', 'payer']
# ['repay', 'rehab']
# slate
# ['outdo', 'digit', 'print', 'front', 'motor', 'thumb', 'ought', 'dutch', 'pithy', 'point', 'robot', 'mount', 'thorn', 'butch', 'input', 'hutch', 'night', 'unfit', 'doubt', 'count', 'tough', 'idiot', 'might', 'toxin', 'tunic', 'thump', 'outgo', 'burnt', 'pitch', 'trout', 'donut', 'third', 'trick', 'tutor', 'grunt', 'touch', 'notch', 'hitch', 'motif', 'crypt', 'trunk', 'wight', 'optic', 'grout', 'torch', 'tying', 'joint', 'orbit', 'thick', 'ingot', 'throw', 'pivot', 'troop', 'botch', 'itchy', 'topic', 'uncut', 'ditch', 'toxic', 'think', 'court', 'throb', 'drift', 'fight', 'toddy', 'tumor', 'tonic', 'trump', 'thigh', 'fruit', 'right', 'brunt', 'tight', 'droit', 'truck', 'thing', 'timid', 'rotor', 'witch', 'thong', 'thrum', 'turbo', 'bigot', 'intro', 'twixt', 'vomit']
# ['digit', 'print', 'drift']
# ['digit']
# slate
# ['abate', 'crate', 'agate', 'grate', 'irate', 'ovate']
# slate
# ['cluck', 'flick', 'fling', 'click', 'clock', 'pluck', 'gloom', 'flood', 'blown', 'fluff', 'flock', 'bluff', 'cling', 'clown', 'glory', 'floor', 'glyph', 'blink', 'clung', 'clink', 'flown', 'cliff', 'blond', 'fluid', 'bloom', 'block', 'blurb', 'plunk', 'blimp', 'flour', 'blind', 'blood', 'climb', 'flunk', 'plumb', 'plump', 'flung', 'cloud', 'clump']
# ['cluck', 'pluck']
# slate
 'acrid', 'mayor', 'randy', 'radar', 'canon', 'pizza', 'baggy', 'mammy', 'nadir', 'havoc', 'annoy', 'kappa', 'bawdy', 'radii', 'dogma', 'nomad', 'cocoa', 'mango', 'rumba', 'audio', 'manic', 'admin', 'macho', 'harpy', 'cairn', 'broad', 'axiom', 'armor', 'jazzy', 'arrow', 'vicar', 'cobra', 'macro', 'baron', 'bacon', 'umbra', 'avian', 'parka', 'avoid', 'circa', 'paddy', 'mambo', 'affix', 'abhor', 'kayak', 'banjo', 'axion', 'ranch', 'mamma', 'cabby', 'magma', 'woman', 'rapid', 'fauna', 'happy', 'mangy', 'organ', 'rayon', 'harry', 'fanny']
# ['major', 'maxim', 'madam', 'macaw', 'march', 'mafia', 'macho', 'macro', 'mambo', 'mamma']
# ['maxim', 'madam', 'mafia', 'mamma']
# slate
# ['model', 'helix', 'whelp', 'linen', 'belly', 'golem', 'belch', 'yield', 'field', 'liver', 'gruel', 'leery', 'libel', 'lover', 'reply', 'dowel', 'bowel', 'vowel', 'kneel', 'quell', 'hovel', 'ruler', 'excel', 'level', 'jelly', 'lower', 'idler', 'wheel', 'dwell', 'rebel', 'bevel', 'lemur', 'novel', 'below', 'cruel', 'jewel', 'wield', 'pixel', 'liner', 'melon', 'leper', 'expel', 'revel', 'cello', 'leggy', 'devil', 'liken', 'lumen', 'welch', 'leech', 'bezel', 'filer', 'lemon', 'lever', 'repel', 'newly', 'relic', 'felon', 'impel', 'peril', 'hello']
# ['linen', 'lower', 'liner', 'liken', 'lumen']
# slate
# ['rebut', 'quiet', 'unmet', 'totem', 'greet', 'tweed', 'comet', 'retch', 'tiger', 'other', 'their', 'depot', 'inert', 'crept', 'retro', 'egret', 'merit', 'inter', 'inept', 'threw', 'recut', 'deter', 'rivet', 'covet', 'octet', 'erupt', 'tenet', 'edict', 'fetid', 'often', 'eight', 'event', 'outer', 'evict', 'enter', 'otter', 'tuber', 'overt', 'ether', 'timer', 'beget', 'tempo', 'debit', 'remit', 'fetch', 'thief', 'tweet', 'duvet', 'detox', 'retry', 'utter', 'debut', 'ethic', 'befit', 'token', 'entry', 'voter', 'tried', 'tenor', 'trend', 'tower', 'truer', 'erect', 'beret', 'exert', 'metro', 'theft', 'meter', 'teddy', 'tepid', 'eject', 'refit']
# ['unmet']
# slate
# ['flesh', 'bless']
# slate
# ['humph', 'mimic', 'pound', 'booby', 'ivory', 'round', 'civic', 'corny', 'fjord', 'dowry', 'boozy', 'duchy', 'groin', 'group', 'bring', 'rhino', 'conic', 'picky', 'unify', 'drink', 'proxy', 'prick', 'crimp', 'wrung', 'humor', 'robin', 'cynic', 'vivid', 'mourn', 'nymph', 'found', 'chunk', 'forgo', 'vouch', 'donor', 'primo', 'brink', 'roomy', 'cinch', 'buggy', 'hunky', 'widow', 'irony', 'fungi', 'whoop', 'bough', 'vigor', 'howdy', 'ionic', 'quirk', 'mummy', 'foggy', 'pooch', 'hippy', 'opium', 'incur', 'funny', 'mound', 'quick', 'grind', 'jiffy', 'woozy', 'muddy', 'onion', 'couch', 'goody', 'frown', 'humid', 'cr
# ['seedy', 'spend', 'speck']
# ['seedy']
# slate
# ['outdo', 'digit', 'print', 'front', 'motor', 'thumb', 'ought', 'dutch', 'pithy', 'point', 'robot', 'mount', 'thorn', 'butch', 'input', 'hutch', 'night', 'unfit', 'doubt', 'count', 'tough', 'idiot', 'might', 'toxin', 'tunic', 'thump', 'outgo', 'burnt', 'pitch', 'trout', 'donut', 'third', 'trick', 'tutor', 'grunt', 'touch', 'notch', 'hitch', 'motif', 'crypt', 'trunk', 'wight', 'optic', 'grout', 'torch', 'tying', 'joint', 'orbit', 'thick', 'ingot', 'throw', 'pivot', 'troop', 'botch', 'itchy', 'topic', 'uncut', 'ditch', 'toxic', 'think', 'court', 'throb', 'drift', 'fight', 'toddy', 'tumor', 'tonic', 'trump', 'thigh', 'fruit', 'right', 'brunt', 'tight', 'droit', 'truck', 'thing', 'timid', 'rotor', 'witch', 'thong', 'thrum', 'turbo', 'bigot', 'intro', 'twixt', 'vomit']
# ['digit', 'print', 'drift']
# ['print']
# slate
# ['yearn', 'peach', 'weary', 'beady', 'beach', 'ready', 'heady', 'rearm', 'beard', 'reach', 'heavy', 'heard']
# ['yearn']
# slate
# ['dwarf', 'crazy', 'drain', 'aback', 'champ', 'crank', 'whack', 'hoard', 'cramp', 'khaki', 'charm', 'wharf', 'coach', 'award', 'chaff', 'brawn', 'ovary', 'brain', 'bravo', 'braid', 'roach', 'diary', 'drank', 'piano', 'prank', 'quack', 'gravy', 'chair', 'quark', 'again', 'knack', 'wrack', 'fraud', 'drawn', 'chard', 'graph', 'foamy', 'brand', 'drama', 'prawn', 'board', 'grain', 'frank', 'grand', 'chain', 'crack', 'guava', 'guard']
# ['drain', 'brawn', 'brain', 'bravo', 'braid', 'gravy', 'fraud', 'drawn', 'graph', 'brand', 'drama', 'prawn', 'grain', 'grand']
# ['drain', 'grain']
# slate
# ['pride', 'bribe', 'biome', 'forge', 'erode', 'gouge', 'rogue', 'rouge', 'prove', 'grime', 'gripe', 'gorge', 'wince', 'dodge', 'choke', 'rupee', 'brine', 'movie', 'purge', 'mince', 'oxide', 'hinge', 'voice', 'wedge', 'midge', 'rhyme', 'prize', 'booze', 'grove', 'pique', 'genre', 'undue', 'eerie', 'price', 'niece', 'diode', 'prone', 'evoke', 'nerve', 'ridge', 'gnome', 'budge', 'ozone', 'queue', 'verve', 'genie', 'dunce', 'prime', 'nudge', 'knife', 'where', 'emcee', 'puree', 'venue', 'pixie', 'penne', 'drove', 'chore', 'grope', 'dirge', 'horde', 'pence', 'creme', 'merge', 'urine', 'fugue', 'bride', 'prude', 'femme', 'probe', 'crepe', 'force', 'verge', 'guide', 'revue', 'crude', 'opine', 'prune', 'vogue', 'chide', 'broke', 'phone', 'binge', 'fence', 'ounce', 'crime', 'imbue', 'drone', 'niche', 'juice', 'ovine', 'borne', 'deuce', 'hedge', 'coupe', 'froze', 'chime', 'curve', 'drive', 'fudge', 'whine', 'crone', 'hence', 'piece', 'judge', 'ombre']
# ['bribe', 'grime', 'brine', 'urine', 'bride', 'drive']
# ['bribe', 'bride']
# slate
# ['stink', 'stout', 'snout', 'story', 'stomp', 'stick', 'sting', 'stuck', 'study', 'swift', 'sport', 'spout', 'stung', 'shunt', 'stood', 'strut', 'stork', 'stony', 'storm', 'stint', 'shift', 'stunt', 'short', 'stock', 'shoot', 'snort', 'stoic', 'shirt', 'spurt', 'stump', 'strip', 'sight', 'shout', 'scout', 'stiff', 'stunk', 'stuff', 'stoop', 'skirt']
# slate
# ['panel', 'lapel', 'label', 'equal', 'laden', 'paler', 'layer', 'hazel', 'relax', 'delay', 'ideal', 'gavel', 'regal', 'fecal', 'relay', 'penal', 'medal', 'renal', 'lager', 'decal', 'pedal', 'navel', 'early', 'bagel', 'abled', 'legal', 'camel', 'angel', 'baler', 'feral', 'fella']
# ['panel', 'hazel', 'navel', 'camel']
# slate
# ['crass', 'quasi', 'chaos', 'brass', 'crash', 'amass', 'brash', 'grass', 'chasm', 'awash', 'grasp', 'gnash', 'quash']
# slate
# ['flume', 'bloke', 'olive', 'elope', 'plume', 'elude', 'glove', 'globe', 'clove', 'glide', 'fluke', 'elide', 'clone']
# ['flume', 'plume', 'elude', 'fluke', 'elide']
# slate
# ['focal', 'naval', 'offal', 'labor', 'badly', 'viral', 'banal', 'caulk', 'royal', 'larva', 'awful', 'lilac', 'valid', 'final', 'valor', 'annul', 'lunar', 'inlay', 'lanky', 'amply', 'molar', 'gayly', 'dally', 'vocal', 'laugh', 'cavil', 'villa', 'viola', 'local', 'modal', 'coral', 'apply', 'bylaw', 'loyal', 'afoul', 'aglow', 'carol', 'canal', 'polar', 'balmy', 'mural', 'moral', 'voila', 'axial', 'daily', 'papal', 'rally', 'cabal', 'ralph', 'zonal', 'anvil', 'madly', 'manly', 'polka', 'rival', 'rural', 'gaily']
# ['offal', 'viral', 'royal', 'modal', 'loyal', 'mural', 'moral', 'rival', 'rural']
# ['offal']
# slate
# ['adobe', 'agree', 'argue', 'badge', 'farce', 'gauze', 'canoe', 'carve', 'awoke', 'range', 'barge', 'azure', 'anime', 'waive', 'naive', 'abide', 'adore', 'mange', 'gaffe', 'cache', 'afire', 'maize', 'dance', 'abode', 'maybe', 'above', 'anode', 'vague', 'mauve', 'payee', 'gauge']
# ['adobe', 'agree', 'argue', 'azure', 'adore', 'abode', 'anode']
# ['agree', 'argue']
# slate
# ['bench', 'feign', 'unfed', 'error', 'wooer', 'goner', 'hyper', 'dozen', 'fixer', 'heron', 'finer', 'perch', 'epoch', 'ferry', 'query', 'perky', 'renew', 'epoxy', 'fewer', 'cheek', 'foyer', 'homer', 'being', 'money', 'power', 'poker', 'woven', 'needy', 'ruder', 'chief', 'enjoy', 'denim', 'piney', 'equip', 'udder', 'given', 'honey', 'derby', 'diner', 'creek', 'embed', 'edify', 'queer', 'venom', 'freer', 'nicer', 'pried', 'index', 'fiber', 'ennui', 'river', 'begun', 'rover', 'woken', 'wreck', 'cover', 'beech', 'joker', 'diver', 'creed', 'vixen', 'geeky', 'check', 'demur', 'queen', 'every', 'inner', 'reign', 'grief', 'creep', 'buyer', 'cyber', 'offer', 'dryer', 'infer', 'credo', 'boxer', 'giver', 'preen', 'wider', 'breed', 'deign', 'fiend', 'envoy', 'brief', 'never', 'fiery', 'cider', 'owner', 'ember', 'recur', 'hover', 'jerky', 'beefy', 'upper', 'mover', 'defer', 'crier', 'drier', 'nerdy', 'hymen', 'freed', 'enemy', 'decor', 'piper', 'riper', 'unwed', 'weedy', 'order', 'widen', 'demon', 'begin', 'under', 'refer', 'rerun', 'cheer', 'miner', 'green', 'covey', 'viper', 'ebony', 'neigh', 'kneed', 'decoy', 'odder', 'weird', 'weigh', 'dicey', 'bicep', 'fever', 'debug', 'video', 'medic', 'women', 'coven', 'purer', 'merry', 'berry', 'cower', 'penny', 'modem', 'greed', 'reedy', 'corer', 'fried', 'boney', 'endow', 'mower', 'gooey', 'eking', 'newer', 'dopey', 'cried', 'dried', 'rider', 'femur', 'decry', 'eying', 'ripen', 'gecko', 'rodeo', 'mercy', 'roger', 'rower']
# ['error', 'recur']
# slate
# ['swirl', 'skill', 'swill', 'spill', 'spoil', 'silky', 'solid', 'silly', 'skulk', 'shyly', 'sulky', 'skull', 'scold', 'spool', 'surly', 'scowl', 'sully']
# ['swirl']
# slate
# ['adobe', 'agree', 'argue', 'badge', 'farce', 'gauze', 'canoe', 'carve', 'awoke', 'range', 'barge', 'azure', 'anime', 'waive', 'naive', 'abide', 'adore', 'mange', 'gaffe', 'cache', 'afire', 'maize', 'dance', 'abode', 'maybe', 'above', 'anode', 'vague', 'mauve', 'payee', 'gauge']
# ['adobe', 'agree', 'argue', 'azure', 'adore', 'abode', 'anode']
# ['agree', 'argue']
# ['argue']
# slate
# ['bleed', 'elder', 'ulcer', 'plier', 'flier', 'flyer', 'bluer', 'clued', 'plied', 'elbow', 'elegy', 'blend', 'olden', 'clerk', 'older', 'elfin', 'bleep', 'fleck']
# slate
# ['delta']
# slate
# ...
# ['rebut', 'depot', 'merit', 'recut', 'debit', 'remit', 'debut', 'befit', 'refit']
# ['merit', 'remit', 'refit']
# ['refit']
# slate
# ['batty', 'patty', 'tatty', 'aunty', 'quota', 'fatty', 'party', 'amity', 'warty', 'cacti', 'ratty', 'junta', 'faith', 'catty', 'aorta']
# ['quota', 'junta', 'aorta']
# ['aorta']
# slate
# ['vital', 'natal', 'atoll', 'fault', 'aptly', 'vault', 'total', 'tubal', 'trial', 'latch', 'tidal', 'tally', 'fatal', 'talon', 'tonal', 'adult', 'octal']
# ['fault', 'vault', 'tally', 'adult']
# ['adult']
# slate
# ['pride', 'bribe', 'biome', 'forge', 'erode', 'gouge', 'rogue', 'rouge', 'prove', 'grime', 'gripe', 'gorge', 'wince', 'dodge', 'choke', 'rupee', 'brine', 'movie', 'purge', 'mince', 'oxide', 'hinge', 'voice', 'wedge', 'midge', 'rhyme', 'prize', 'booze', 'grove', 'pique', 'genre', 'undue', 'eerie', 'price', 'niece', 'diode', 'prone', 'evoke', 'nerve', 'ridge', 'gnome', 'budge', 'ozone', 'queue', 'verve', 'genie', 'dunce', 'prime', 'nudge', 'knife', 'where', 'emcee', 'puree', 'venue', 'pixie', 'penne', 'drove', 'chore', 'grope', 'dirge', 'horde', 'pence', 'creme', 'merge', 'urine', 'fugue', 'bride', 'prude', 'femme', 'probe', 'crepe', 'force', 'verge', 'guide', 'revue', 'crude', 'opine', 'prune', 'vogue', 'chide', 'broke', 'phone', 'binge', 'fence', 'ounce', 'crime', 'imbue', 'drone', 'niche', 'juice', 'ovine', 'borne', 'deuce', 'hedge', 'coupe', 'froze', 'chime', 'curve', 'drive', 'fudge', 'whine', 'crone', 'hence', 'piece', 'judge', 'ombre']
# ['gouge', 'dodge', 'wedge', 'booze', 'undue', 'evoke', 'gnome', 'budge', 'ozone', 'queue', 'nudge', 'venue', 'fugue', 'femme', 'vogue', 'hedge', 'fudge', 'judge']
# ['budge', 'nudge', 'judge']
# ['nudge', 'judge']
# ['judge']
# slate
# ['bench', 'feign', 'unfed', 'error', 'wooer', 'goner', 'hyper', 'dozen', 'fixer', 'heron', 'finer', 'perch', 'epoch', 'ferry', 'query', 'perky', 'renew', 'epoxy', 'fewer', 'cheek', 'foyer', 'homer', 'being', 'money', 'power', 'poker', 'woven', 'needy', 'ruder', 'chief', 'enjoy', 'denim', 'piney', 'equip', 'udder', 'given', 'honey', 'derby', 'diner', 'creek', 'embed', 'edify', 'queer', 'venom', 'freer', 'nicer', 'pried', 'index', 'fiber', 'ennui', 'river', 'begun', 'rover', 'woken', 'wreck', 'cover', 'beech', 'joker', 'diver', 'creed', 'vixen', 'geeky', 'check', 'demur', 'queen', 'every', 'inner', 'reign', 'grief', 'creep', 'buyer', 'cyber', 'offer', 'dryer', 'infer', 'credo', 'boxer', 'giver', 'preen', 'wider', 'breed', 'deign', 'fiend', 'envoy', 'brief', 'never', 'fiery', 'cider', 'owner', 'ember', 'recur', 'hover', 'jerky', 'beefy', 'upper', 'mover', 'defer', 'crier', 'drier', 'nerdy', 'hymen', 'freed', 'enemy', 'decor', 'piper', 'riper', 'unwed', 'weedy', 'order', 'widen', 'demon', 'begin', 'under', 'refer', 'rerun', 'cheer', 'miner', 'green', 'covey', 'viper', 'ebony', 'neigh', 'kneed', 'decoy', 'odder', 'weird', 'weigh', 'dicey', 'bicep', 'fever', 'debug', 'video', 'medic', 'women', 'coven', 'purer', 'merry', 'berry', 'cower', 'penny', 'modem', 'greed', 'reedy', 'corer', 'fried', 'boney', 'endow', 'mower', 'gooey', 'eking', 'newer', 'dopey', 'cried', 'dried', 'rider', 'femur', 'decry', 'eying', 'ripen', 'gecko', 'rodeo', 'mercy', 'roger', 'rower']
# ['wooer', 'goner', 'hyper', 'homer', 'power', 'poker', 'nicer', 'river', 'rover', 'cover', 'joker', 'inner', 'buyer', 'cyber', 'boxer', 'giver', 'owner', 'hover', 'upper', 'mover', 'crier', 'piper', 'riper', 'miner', 'viper', 'purer', 'cower', 'corer', 'mower', 'roger', 'rower']
# ['roger', 'rower']
# ['rower']
# slate
# ['ascot', 'angst', 'waist', 'patsy', 'artsy']
# ['artsy']
# slate
# ['parry', 'hairy', 'wacky', 'carry', 'daddy', 'fairy', 'caddy', 'hardy', 'dairy', 'bawdy', 'harpy', 'jazzy', 'paddy', 'cabby', 'happy', 'harry']
# slate
# ['nasty', 'vista', 'tasty', 'pasta', 'pasty', 'hasty']
# ['nasty', 'tasty', 'hasty']
# ['tasty', 'hasty']
# ['hasty']
# slate
# ['humph', 'mimic', 'pound', 'booby', 'ivory', 'round', 'civic', 'corny', 'fjord', 'dowry', 'boozy', 'duchy', 'groin', 'group', 'bring', 'rhino', 'conic', 'picky', 'unify', 'drink', 'proxy', 'prick', 'crimp', 'wrung', 'humor', 'robin', 'cynic', 'vivid', 'mourn', 'nymph', 'found', 'chunk', 'forgo', 'vouch', 'donor', 'primo', 'brink', 'roomy', 'cinch', 'buggy', 'hunky', 'widow', 'irony', 'fungi', 'whoop', 'bough', 'vigor', 'howdy', 'ionic', 'quirk', 'mummy', 'foggy', 'pooch', 'hippy', 'opium', 'incur', 'funny', 'mound', 'quick', 'grind', 'jiffy', 'woozy', 'muddy', 'onion', 'couch', 'goody', 'frown', 'humid', 'crock', 'birch', 'winch', 'chump', 'moron', 'croup', 'juicy', 'crook', 'icing', 'rigor', 'poppy', 'dowdy', 'dumpy', 'horny', 'doing', 'dying', 'buddy', 'chord', 'crowd', 'privy', 'bongo', 'pudgy', 'choir', 'crick', 'furor', 'cough', 'furry', 'crump', 'dough', 'unzip', 'minor', 'murky', 'buxom', 'porch', 'dingo', 'brood', 'piggy', 'which', 'pouch', 'crown', 'woody', 'comic', 'frock', 'drunk', 'prong', 'worry', 'finch', 'groom', 'young', 'frond', 'ovoid', 'chuck', 'puppy', 'bunny', 'jumbo', 'conch', 'droop', 'rugby', 'micro', 'comfy', 'gruff', 'rocky', 'grown', 'cumin', 'rigid', 'rowdy', 'mucky', 'bingo', 'honor', 'phony', 'brick', 'vying', 'hippo', 'ruddy', 'windy', 'crumb', 'dummy', 'broom', 'hobby', 'idiom', 'chick', 'whiny', 'whiff', 'wrong', 'hunch', 'puffy', 'curio', 'churn', 'wimpy', 'juror', 'morph', 'moody', 'fuzzy', 'cubic', 'briny', 'bound', 'proud', 'gumbo', 'dizzy', 'brook', 'ninny', 'owing', 'minim', 'rough', 'wordy', 'funky', 'dingy', 'proof', 'dodgy', 'myrrh', 'prior', 'pinky', 'chock', 'forum', 'jumpy', 'giddy', 'rumor', 'wound', 'inbox', 'fizzy', 'kinky', 'grimy', 'curvy', 'biddy', 'curry', 'occur', 'pubic', 'munch', 'hurry', 'pygmy', 'wring', 'drown', 'guppy', 'union', 'druid', 'crony', 'bunch', 'known', 'punch', 'downy', 'goofy', 'gummy', 'chirp', 'gourd', 'brown', 'pinch', 'going', 'hound', 'undid', 'knock', 'condo', 'bobby', 'hydro']
# ['hydro']
# slate
# ['delve', 'rifle', 'guile', 'melee', 'exile', 'cycle', 'boule', 'bilge', 'lodge', 'while', 'lunge', 'bible', 'uncle', 'bugle', 'noble', 'whole', 'bulge', 'belie', 'ledge', 'belle', 'liege']
# ['lodge', 'lunge', 'liege']
# ['lunge', 'liege']
# ['liege']
# slate
# ['vital', 'natal', 'atoll', 'fault', 'aptly', 'vault', 'total', 'tubal', 'trial', 'latch', 'tidal', 'tally', 'fatal', 'talon', 'tonal', 'adult', 'octal']
# ['octal']
# slate
# ['pride', 'bribe', 'biome', 'forge', 'erode', 'gouge', 'rogue', 'rouge', 'prove', 'grime', 'gripe', 'gorge', 'wince', 'dodge', 'choke', 'rupee', 'brine', 'movie', 'purge', 'mince', 'oxide', 'hinge', 'voice', 'wedge', 'midge', 'rhyme', 'prize', 'booze', 'grove', 'pique', 'genre', 'undue', 'eerie', 'price', 'niece', 'diode', 'prone', 'evoke', 'nerve', 'ridge', 'gnome', 'budge', 'ozone', 'queue', 'verve', 'genie', 'dunce', 'prime', 'nudge', 'knife', 'where', 'emcee', 'puree', 'venue', 'pixie', 'penne', 'drove', 'chore', 'grope', 'dirge', 'horde', 'pence', 'creme', 'merge', 'urine', 'fugue', 'bride', 'prude', 'femme', 'probe', 'crepe', 'force', 'verge', 'guide', 'revue', 'crude', 'opine', 'prune', 'vogue', 'chide', 'broke', 'phone', 'binge', 'fence', 'ounce', 'crime', 'imbue', 'drone', 'niche', 'juice', 'ovine', 'borne', 'deuce', 'hedge', 'coupe', 'froze', 'chime', 'curve', 'drive', 'fudge', 'whine', 'crone', 'hence', 'piece', 'judge', 'ombre']
# ['forge', 'rogue', 'rouge', 'gorge', 'rhyme', 'genre', 'nerve', 'verve', 'where', 'horde', 'merge', 'verge', 'revue', 'borne', 'ombre']
# ['ombre']
# slate
# ['paper', 'repay', 'kebab', 'enema', 'break', 'abbey', 'ahead', 'gamer', 'creak', 'parer', 'recap', 'dream', 'baker', 'cream', 'decay', 'rebar', 'rehab', 'zebra', 'aider', 'ocean', 'haven', 'harem', 'arena', 'bread', 'freak', 'amend', 'ramen', 'caper', 'wager', 'oaken', 'racer', 'cedar', 'cheap', 'media', 'dread', 'waxen', 'gazer', 'annex', 'omega', 'cameo', 'debar', 'maker', 'began', 'eager', 'hyena', 'rarer', 'waver', 'wafer', 'wreak', 'apnea', 'gayer', 'opera', 'amber', 'cagey', 'pecan', 'raven', 'vegan', 'knead', 'anger', 'mecca', 'payer']
# ['paper', 'gamer', 'baker', 'wager', 'gazer', 'maker', 'eager', 'waver', 'wafer', 'gayer', 'payer']
# ['paper', 'baker', 'maker', 'payer']
# ['payer']
# slate
# ['south', 'sixth', 'sooty', 'sixty', 'smith', 'sooth']
# slate
# ['chest', 'heist', 'fetus', 'upset', 'onset', 'exist', 'wrest', 'reset', 'beset', 'guest', 'crest', 'ester', 'ethos', 'quest', 'unset']
# ['upset', 'onset', 'unset']
# slate
# ['moult', 'pilot', 'troll', 'light', 'built', 'twirl', 'hotly', 'tulip', 'until', 'truly', 'quilt', 'guilt', 'limit', 'unlit']
# ['unlit']
# slate
# ['outdo', 'digit', 'print', 'front', 'motor', 'thumb', 'ought', 'dutch', 'pithy', 'point', 'robot', 'mount', 'thorn', 'butch', 'input', 'hutch', 'night', 'unfit', 'doubt', 'count', 'tough', 'idiot', 'might', 'toxin', 'tunic', 'thump', 'outgo', 'burnt', 'pitch', 'trout', 'donut', 'third', 'trick', 'tutor', 'grunt', 'touch', 'notch', 'hitch', 'motif', 'crypt', 'trunk', 'wight', 'optic', 'grout', 'torch', 'tying', 'joint', 'orbit', 'thick', 'ingot', 'throw', 'pivot', 'troop', 'botch', 'itchy', 'topic', 'uncut', 'ditch', 'toxic', 'think', 'court', 'throb', 'drift', 'fight', 'toddy', 'tumor', 'tonic', 'trump', 'thigh', 'fruit', 'right', 'brunt', 'tight', 'droit', 'truck', 'thing', 'timid', 'rotor', 'witch', 'thong', 'thrum', 'turbo', 'bigot', 'intro', 'twixt', 'vomit']
# ['motor', 'point', 'robot', 'motif', 'joint', 'rotor', 'vomit']
# ['vomit']
# slate
# ['cigar', 'karma', 'major', 'marry', 'croak', 'maxim', 'parry', 'gamma', 'briar', 'gaudy', 'vodka', 'radio', 'favor', 'panic', 'aroma', 'comma', 'foray', 'cargo', 'hairy', 'canny', 'bayou', 'manor', 'apron', 'cacao', 'gawky', 'madam', 'augur', 'wacky', 'angry', 'aphid', 'dandy', 'carry', 'rainy', 'daddy', 'aging', 'mocha', 'pagan', 'human', 'manga', 'groan', 'fairy', 'ardor', 'nanny', 'handy', 'ninja', 'vapor', 'acorn', 'aping', 'mania', 'borax', 'china', 'rabid', 'caddy', 'magic', 'macaw', 'candy', 'march', 'arbor', 'hardy', 'razor', 'wagon', 'cabin', 'fancy', 'friar', 'dairy', 'among', 'rabbi', 'agony', 'urban', 'rajah', 'gonad', 'adorn', 'mafia', 'array', 'vapid', 'acrid', 'mayor', 'randy', 'radar', 'canon', 'pizza', 'baggy', 'mammy', 'nadir', 'havoc', 'annoy', 'kappa', 'bawdy', 'radii', 'dogma', 'nomad', 'cocoa', 'mango', 'rumba', 'audio', 'manic', 'admin', 'macho', 'harpy', 'cairn', 'broad', 'axiom', 'armor', 'jazzy', 'arrow', 'vicar', 'cobra', 'macro', 'baron', 'bacon', 'umbra', 'avian', 'parka', 'avoid', 'circa', 'paddy', 'mambo', 'affix', 'abhor', 'kayak', 'banjo', 'axion', 'ranch', 'mamma', 'cabby', 'magma', 'woman', 'rapid', 'fauna', 'happy', 'mangy', 'organ', 'rayon', 'harry', 'fanny']
# ['canny', 'dandy', 'nanny', 'handy', 'candy', 'fancy', 'randy', 'fanny']
# ['nanny', 'fanny']
# ['fanny']

# %%
# Get number of unsuccessful tries:
tries.count(-1)
# Out:
# 14

# %%
# % Successful
print(f"{((len(tries)-tries.count(-1)) / len(tries)) * 100:.2f}%")
# Out:
# 99.39%

# %%
# % Unsuccessful:
print(f"{(tries.count(-1) / len(tries)) * 100:.2f}%")
# Out:
# 0.61%

# %%
# Remove all -1's from tries
tries_successful = [i for i in tries if i != -1]

# %% [markdown]
# Lets see how many turns we need on average to get the word right:

# %%
np.mean(tries_successful)
# Out:
# 3.6549019607843136

# %% [markdown]
# We need around 3.65 turns to get the word right! Not bad.

# %% [markdown]
# # Done! (I've wasted too much time on this 😅)
